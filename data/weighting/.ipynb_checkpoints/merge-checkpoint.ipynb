# %%
import pandas as pd

# %%
df_mindful = pd.read_csv("wayid2weights_mindful.csv")
df_vibrant = pd.read_csv("wayid2weights_vibrant.csv")

# df_mindful = df_mindful.rename(columns = {
#     "environment":"environment_mindful",
#     "support":"support_mindful",
#     "safety":"safety_mindful",
# })

# df_vibrant = df_vibrant.rename(columns = {
#     "environment":"environment_vibrant",
#     "support":"support_vibrant",
#     "safety":"safety_vibrant",
# })

# %%
df_mindful.head()
# Out:
#        wayid        lat       lon  numpics  environment   support    safety
# 0   50149963  51.503563 -0.119305   131032     0.594617  0.819791  0.470506
# 1   39093506  51.506645 -0.127307   107570     0.510304  0.380889  0.376884
# 2   98477125  51.506116 -0.126964   103943     0.511229  0.393047  0.376884
# 3  300869142  51.506046 -0.127061   103714     0.512048  0.393047  0.376884
# 4  230505803  51.506046 -0.127061   102059     0.514975  0.380659  0.478475

# %%
df_vibrant.head()
# Out:
#        wayid        lat       lon  numpics  environment   support    safety
# 0   50149963  51.503563 -0.119305   131032     0.619842  0.876253  0.470506
# 1   39093506  51.506645 -0.127307   107570     0.520761  0.404201  0.376884
# 2   98477125  51.506116 -0.126964   103943     0.521941  0.438985  0.376884
# 3  300869142  51.506046 -0.127061   103714     0.522877  0.438985  0.376884
# 4  230505803  51.506046 -0.127061   102059     0.526303  0.419026  0.478475

# %%
df_mindful = df_mindful.set_index("wayid")
df_vibrant = df_vibrant.set_index("wayid")

# %%
df = df_mindful.join(df_vibrant, lsuffix="_mindful", rsuffix="_vibrant")
df.rename(columns={"numpics_mindful":"numpics"})
df.head()
# Out:
#            lat_mindful  lon_mindful  numpics_mindful  environment_mindful  \
# wayid
# 50149963     51.503563    -0.119305           131032             0.594617
# 39093506     51.506645    -0.127307           107570             0.510304
# 98477125     51.506116    -0.126964           103943             0.511229
# 300869142    51.506046    -0.127061           103714             0.512048
# 230505803    51.506046    -0.127061           102059             0.514975
#
#            support_mindful  safety_mindful  lat_vibrant  lon_vibrant  \
# wayid
# 50149963          0.819791        0.470506    51.503563    -0.119305
# 39093506          0.380889        0.376884    51.506645    -0.127307
# 98477125          0.393047        0.376884    51.506116    -0.126964
# 300869142         0.393047        0.376884    51.506046    -0.127061
# 230505803         0.380659        0.478475    51.506046    -0.127061
#
#            numpics_vibrant  environment_vibrant  support_vibrant  \
# wayid
# 50149963            131032             0.619842         0.876253
# 39093506            107570             0.520761         0.404201
# 98477125            103943             0.521941         0.438985
# 300869142           103714             0.522877         0.438985
# 230505803           102059             0.526303         0.419026
#
#            safety_vibrant
# wayid
# 50149963         0.470506
# 39093506         0.376884
# 98477125         0.376884
# 300869142        0.376884
# 230505803        0.478475
